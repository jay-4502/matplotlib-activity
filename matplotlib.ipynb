# %% [markdown]
# <a href="https://colab.research.google.com/github/jay-4502/project1/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[20,30,50,60]
y=[10,20,30,50]
plt.plot(x,y)

# %%
plt.plot(x,y,color='Green',marker='D',markersize=6)

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
x=[1,2,3,4,5]
y=[10,20,30,40,50]
plt.plot(x,y,color='red',linewidth=2,linestyle='dotted')

# %%
students=['A','B','C','D']
score=[20,30,21,18]
plt.bar(students,score)
# Out:
# <BarContainer object of 4 artists>

# %%
exp_student=[500,800,200,1000]
exp_branch=['cse','ise','ece','ai']
plt.pie(exp_student,labels=exp_branch,radius=1,autopct='%0.2f%%',shadow=True,explode=[0,0,0.4,0],startangle=30)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f1bd975a4d0>,
# ...
#  [Text(0.44741029797482756, 1.0049000075958185, 'cse'),
#   Text(-1.0310101870051112, 0.38342925591520277, 'ise'),
#   Text(-0.9317217078385512, -1.1755401563291716, 'ece'),
#   Text(0.817459294242457, -0.7360436823019572, 'ai')],
#  [Text(0.24404198071354227, 0.5481272768704465, '20.00%'),
#   Text(-0.5623691929118787, 0.2091432304992015, '32.00%'),
#   Text(-0.6211478052257008, -0.7836934375527811, '8.00%'),
#   Text(0.44588688776861285, -0.40147837216470383, '40.00%')])

# %%
import numpy as np
xpos=np.arange(len(students))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
profit=[10,20,40,30]
plt.bar(xpos,score,label="score")
plt.legend()

# %%
cse_students=[100,30,40,60,70,120,90]
eee_students=[70,50,123,124,130,150,100]
plt.hist([cse_students,eee_students],bins=[80,100,125,150],rwidth=0.9,color=['red','blue'],label=['cse','eee'])
plt.legend()
